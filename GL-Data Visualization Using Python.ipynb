# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#set a style (color code) for seaborn package
sns.set(color_codes=True)

# %%
auto=pd.read_csv("C:/Users/AKANSHA BHATT/Downloads/Automobile (1).csv")

# %%
auto.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                168  alfa-romero       gas        std
# 1          3                168  alfa-romero       gas        std
# 2          1                168  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   number_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0             two  convertible          rwd           front        88.6  ...
# 1             two  convertible          rwd           front        88.6  ...
# 2             two    hatchback          rwd           front        94.5  ...
# 3            four        sedan          fwd           front        99.8  ...
# 4            four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak_rpm city_mpg  highway_mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# # Univariant Analysis:

# %% [markdown]
# Distplot

# %%
sns.distplot(auto['normalized_losses'])
plt.show()

# %%
sns.distplot(auto['engine_size'])
plt.show()

# %%
sns.distplot(auto['city_mpg'])
plt.show()

# %%
sns.distplot(auto['city_mpg'],kde=False,rug=True)             #Histogram without kernel density estimation
plt.show()

# %%
sns.distplot(auto['normalized_losses'],kde=False,rug=True)
plt.show()

# %% [markdown]
# # Bivariant Analysis:

# %% [markdown]
# Joint Plot

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'])
plt.show()

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'])
plt.show()

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'],kind='hex')
plt.show()

# %% [markdown]
# Residual Plot

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'],kind='resid')
plt.show()

# %% [markdown]
# Regression Plot

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'],kind='reg')
plt.show()

# %% [markdown]
# Kde Plot

# %%
sns.jointplot(auto['engine_size'],auto['horsepower'],kind='kde')
plt.show()

# %% [markdown]
# # Mulitivariant Analysis:

# %% [markdown]
# Pair Plot

# %%
sns.pairplot(auto[['normalized_losses','engine_size','horsepower']])

# %% [markdown]
# # Creating 2-D plot

# %% [markdown]
# Strip Plot

# %%
sns.stripplot(auto['fuel_type'],auto['horsepower'],jitter=True)

# %% [markdown]
# Swarm Plot

# %%
sns.swarmplot(auto['fuel_type'],auto['horsepower'])

# %% [markdown]
# Boxplot

# %%
sns.boxplot(auto['number_of_doors'],auto['horsepower'],hue=auto['fuel_type'])

# %% [markdown]
# Bar Plot

# %%
sns.barplot(auto['body_style'],auto['horsepower'],hue=auto['engine_location'])

# %% [markdown]
# Count Plot

# %%
sns.countplot(auto['body_style'],hue=auto['engine_location'])

# %% [markdown]
# Point Plot

# %%
sns.pointplot(auto['fuel_system'],auto['horsepower'],hue=auto['number_of_doors'])

# %% [markdown]
# Factor Plot

# %%
sns.factorplot(x='fuel_type',
              y='horsepower',
              hue='number_of_doors',
              col='engine_location',
              data=auto,
              kind='bar')                  #various types of kind plot: bar, strip, point,count,box,violin
# Out:
# C:\Users\AKANSHA BHATT\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# lmplot

# %%
sns.lmplot(x='horsepower',y='peak_rpm',data=auto,hue='fuel_type')
